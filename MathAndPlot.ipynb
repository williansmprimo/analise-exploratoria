# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rand_values = np.random.normal(10,30, 1000) #start, end, size
rand_values
# Out:
# array([ 1.72804423e+01,  2.67350673e+01, -1.84331150e+00, -2.36845806e+01,
#        -2.58990457e+00, -4.39857897e+01, -1.18348870e+01,  3.08210742e+01,
#        -5.90069245e+00,  2.74955366e+01,  2.51860815e+01,  2.36655956e+01,
#         2.39660937e+01, -2.73116965e+01,  1.98812624e+01,  2.75936465e+01,
#         2.15757459e+01,  5.19008962e+01,  5.62849455e+01, -1.72219923e+01,
#        -3.64951384e+01,  2.49532423e+01, -4.42368059e+01,  1.08869369e+01,
#        -1.90166349e+01,  8.51748897e+00,  4.68273729e+01,  4.81379289e+01,
#         4.45956519e+01,  2.46466426e+01,  4.32978544e+01, -2.34228714e+01,
#         1.81031102e+01,  2.26356224e+01, -1.56518982e+01,  3.49840826e+01,
#         3.32800349e+01,  1.40161448e+01,  1.37049431e+01,  9.86829346e+00,
#         2.12608802e+01,  4.24982550e+01,  3.80342178e+01, -4.14870909e+01,
#         2.08525833e+01,  2.35065930e+01,  2.42137911e+00,  6.87441382e+00,
# ...

# %%
rand_values.mean()
# Out:
# 3.3657497126291065

# %%
np.median(rand_values)
# Out:
# 5.793047424011446

# %%
plt.hist(rand_values, 50)
# Out:
# (array([ 1.,  1.,  1.,  1.,  2.,  1.,  3.,  6., 10.,  5.,  9., 19., 10.,
#         15., 21., 26., 27., 41., 34., 35., 47., 37., 50., 50., 57., 44.,
#         59., 44., 56., 39., 46., 26., 31., 25., 25., 16., 16., 16., 10.,
#          9., 14.,  4.,  2.,  5.,  1.,  0.,  0.,  0.,  0.,  3.]),
#  array([-84.75595747, -80.98989316, -77.22382885, -73.45776454,
#         -69.69170024, -65.92563593, -62.15957162, -58.39350731,
#         -54.62744301, -50.8613787 , -47.09531439, -43.32925008,
#         -39.56318577, -35.79712147, -32.03105716, -28.26499285,
#         -24.49892854, -20.73286423, -16.96679993, -13.20073562,
#          -9.43467131,  -5.668607  ,  -1.9025427 ,   1.86352161,
#           5.62958592,   9.39565023,  13.16171454,  16.92777884,
#          20.69384315,  24.45990746,  28.22597177,  31.99203608,
#          35.75810038,  39.52416469,  43.290229  ,  47.05629331,
#          50.82235761,  54.58842192,  58.35448623,  62.12055054,
# ...

# %%
rand_values.std()
# Out:
# 29.54883658509438

# %%
rand_values.var()
# Out:
# 873.1337435326122

# %%
from scipy.stats import norm

# %%
x = np.arange(-3, 3, 0.001)
x
# Out:
# array([-3.   , -2.999, -2.998, ...,  2.997,  2.998,  2.999])

# %%
len(x)
# Out:
# 6000

# %%
plt.plot(x, norm.pdf(x))

# %%
mean = 5.0
stdDev = 2.0
values = np.random.normal(mean, stdDev, 10000)
plt.hist(values, 50)
# Out:
# (array([  3.,   3.,   2.,   4.,   7.,  12.,  10.,  26.,  32.,  51.,  52.,
#          94., 101., 144., 188., 210., 275., 326., 355., 407., 462., 465.,
#         487., 520., 555., 594., 602., 570., 494., 450., 437., 377., 354.,
#         268., 237., 184., 161., 130.,  83.,  90.,  44.,  50.,  19.,  23.,
#          17.,  11.,   7.,   3.,   0.,   4.]),
#  array([-2.22574275, -1.94013132, -1.65451989, -1.36890846, -1.08329703,
#         -0.7976856 , -0.51207416, -0.22646273,  0.0591487 ,  0.34476013,
#          0.63037156,  0.91598299,  1.20159442,  1.48720585,  1.77281729,
#          2.05842872,  2.34404015,  2.62965158,  2.91526301,  3.20087444,
#          3.48648587,  3.77209731,  4.05770874,  4.34332017,  4.6289316 ,
#          4.91454303,  5.20015446,  5.48576589,  5.77137733,  6.05698876,
#          6.34260019,  6.62821162,  6.91382305,  7.19943448,  7.48504591,
#          7.77065735,  8.05626878,  8.34188021,  8.62749164,  8.91310307,
# ...

# %%
from scipy.stats import expon

# %%
x = np.arange(0, 10, 0.001)
plt.plot(x, expon.pdf(x))

# %%
from scipy.stats import poisson

# %%
mean = 500
x = np.arange(400, 600, 0.5)
plt.plot(x, poisson.pmf(x, mean))

# %%
np.percentile(x, 50)
# Out:
# 499.75

# %%
x = np.arange(-3, 3, 0.001)

# %%
plt.rcdefaults()
plt.axes().grid()
plt.axes().set_xlim([-5, 5])
plt.axes().set_ylim([-0.01, 1.1])
plt.xlabel('Label X')
plt.ylabel('Label Y')
plt.plot(x, norm.pdf(x), 'b-')
plt.plot(x, norm.pdf(x, 1.0, 0.5), 'r:')
plt.legend(['Legenda 01', 'Lgenda 02'], loc=1)
plt.savefig('./fig.png', format='png')

# %%
np.percentile(x, 100)
# Out:
# 2.2379558285396173

# %%
values = [0.3, 0.4, 0.2, 0.1]
colors = ['r', 'g', 'b', 'm']
explode = [0, 0, 0, 0.3]
labels = ['R', 'G', 'B', 'M']
plt.title="Colors"
plt.pie(values, colors=colors, labels=labels, explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x7a3aef049b40>,
# ...
#  [Text(0.6465637441936395, 0.8899187180267095, 'R'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, 'G'),
#   Text(0.3399188211458418, -1.0461621265515308, 'B'),
#   Text(1.3314791815456888, -0.43262361136491756, 'M')])

# %%
values = [10, 50, 20, 69]
plt.bar(range(0,4), values, color=colors)
# Out:
# <BarContainer object of 4 artists>

# %%
import math
x = np.random.normal(10, 0.5, 100)
y = np.random.normal(10, 0.5, 100)
plt.scatter(x, y)
plt.plot(x, x, 'r--')
plt.plot(x, [_x +1  for _x in x], 'm--')
